# %% [markdown]
# ## Predictive Maintenance Classification

# %%
# importing libraries 
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings("ignore")

# %%
pip install category_encoders
# Out:
# Collecting category_encoders
#   Downloading category_encoders-2.6.4-py2.py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: numpy>=1.14.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from category_encoders) (1.26.2)
# Requirement already satisfied: scikit-learn>=0.20.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from category_encoders) (1.5.2)
# Requirement already satisfied: scipy>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from category_encoders) (1.11.2)
# Requirement already satisfied: statsmodels>=0.9.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from category_encoders) (0.14.0)
# Requirement already satisfied: pandas>=1.0.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from category_encoders) (2.1.3)
# Requirement already satisfied: patsy>=0.5.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from category_encoders) (0.5.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas>=1.0.5->category_encoders) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas>=1.0.5->category_encoders) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas>=1.0.5->category_encoders) (2023.3)
# Requirement already satisfied: six in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from patsy>=0.5.1->category_encoders) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from scikit-learn>=0.20.0->category_encoders) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from scikit-learn>=0.20.0->category_encoders) (3.5.0)
# Requirement already satisfied: packaging>=21.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from statsmodels>=0.9.0->category_encoders) (23.1)
# Downloading category_encoders-2.6.4-py2.py3-none-any.whl (82 kB)
# Installing collected packages: category_encoders
# Successfully installed category_encoders-2.6.4
# Note: you may need to restart the kernel to use updated packages.

# %%
#Default theme
sns.set_theme(palette='tab10',
              font='Lucida Calligraphy',
              font_scale=1.5,
              rc=None)

import matplotlib
matplotlib.rcParams.update({'font.size': 15})
plt.style.use('dark_background')

# %%
pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows",None)

# %%
df = pd.read_csv('predictive_maintenance.csv')

# %%
df.head()
# Out:
#    UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 0    1     M14860    M                298.1                    308.6
# 1    2     L47181    L                298.2                    308.7
# 2    3     L47182    L                298.1                    308.5
# 3    4     L47183    L                298.2                    308.6
# 4    5     L47184    L                298.2                    308.7
#
#    Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target Failure Type
# 0                    1551         42.8                0       0   No Failure
# 1                    1408         46.3                3       0   No Failure
# 2                    1498         49.4                5       0   No Failure
# 3                    1433         39.5                7       0   No Failure
# 4                    1408         40.0                9       0   No Failure

# %%
#Dropping product id & udi 
df = df.drop(["UDI","Product ID"],axis=1)

# %%
df.head()
# Out:
#   Type  Air temperature [K]  Process temperature [K]  Rotational speed [rpm]  \
# 0    M                298.1                    308.6                    1551
# 1    L                298.2                    308.7                    1408
# 2    L                298.1                    308.5                    1498
# 3    L                298.2                    308.6                    1433
# 4    L                298.2                    308.7                    1408
#
#    Torque [Nm]  Tool wear [min]  Target Failure Type
# 0         42.8                0       0   No Failure
# 1         46.3                3       0   No Failure
# 2         49.4                5       0   No Failure
# 3         39.5                7       0   No Failure
# 4         40.0                9       0   No Failure

# %%
df.sample(10).style.set_properties(
    **{
        'background-color': 'Brown',
        'color': 'white',
        'border-color': 'White'
    })
# Out:
# <style type="text/css">
# #T_65069_row0_col0, #T_65069_row0_col1, #T_65069_row0_col2, #T_65069_row0_col3, #T_65069_row0_col4, #T_65069_row0_col5, #T_65069_row0_col6, #T_65069_row0_col7, #T_65069_row1_col0, #T_65069_row1_col1, #T_65069_row1_col2, #T_65069_row1_col3, #T_65069_row1_col4, #T_65069_row1_col5, #T_65069_row1_col6, #T_65069_row1_col7, #T_65069_row2_col0, #T_65069_row2_col1, #T_65069_row2_col2, #T_65069_row2_col3, #T_65069_row2_col4, #T_65069_row2_col5, #T_65069_row2_col6, #T_65069_row2_col7, #T_65069_row3_col0, #T_65069_row3_col1, #T_65069_row3_col2, #T_65069_row3_col3, #T_65069_row3_col4, #T_65069_row3_col5, #T_65069_row3_col6, #T_65069_row3_col7, #T_65069_row4_col0, #T_65069_row4_col1, #T_65069_row4_col2, #T_65069_row4_col3, #T_65069_row4_col4, #T_65069_row4_col5, #T_65069_row4_col6, #T_65069_row4_col7, #T_65069_row5_col0, #T_65069_row5_col1, #T_65069_row5_col2, #T_65069_row5_col3, #T_65069_row5_col4, #T_65069_row5_col5, #T_65069_row5_col6, #T_65069_row5_col7, #T_65069_row6_col0, #T_65069_row6_col1, #T_65069_row6_col2, #T_65069_row6_col3, #T_65069_row6_col4, #T_65069_row6_col5, #T_65069_row6_col6, #T_65069_row6_col7, #T_65069_row7_col0, #T_65069_row7_col1, #T_65069_row7_col2, #T_65069_row7_col3, #T_65069_row7_col4, #T_65069_row7_col5, #T_65069_row7_col6, #T_65069_row7_col7, #T_65069_row8_col0, #T_65069_row8_col1, #T_65069_row8_col2, #T_65069_row8_col3, #T_65069_row8_col4, #T_65069_row8_col5, #T_65069_row8_col6, #T_65069_row8_col7, #T_65069_row9_col0, #T_65069_row9_col1, #T_65069_row9_col2, #T_65069_row9_col3, #T_65069_row9_col4, #T_65069_row9_col5, #T_65069_row9_col6, #T_65069_row9_col7 {
#   background-color: Brown;
#   color: white;
#   border-color: White;
# }
# </style>
# <table id="T_65069">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_65069_level0_col0" class="col_heading level0 col0" >Type</th>
#       <th id="T_65069_level0_col1" class="col_heading level0 col1" >Air temperature [K]</th>
#       <th id="T_65069_level0_col2" class="col_heading level0 col2" >Process temperature [K]</th>
#       <th id="T_65069_level0_col3" class="col_heading level0 col3" >Rotational speed [rpm]</th>
#       <th id="T_65069_level0_col4" class="col_heading level0 col4" >Torque [Nm]</th>
#       <th id="T_65069_level0_col5" class="col_heading level0 col5" >Tool wear [min]</th>
#       <th id="T_65069_level0_col6" class="col_heading level0 col6" >Target</th>
#       <th id="T_65069_level0_col7" class="col_heading level0 col7" >Failure Type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_65069_level0_row0" class="row_heading level0 row0" >5431</th>
#       <td id="T_65069_row0_col0" class="data row0 col0" >L</td>
#       <td id="T_65069_row0_col1" class="data row0 col1" >302.800000</td>
#       <td id="T_65069_row0_col2" class="data row0 col2" >312.500000</td>
#       <td id="T_65069_row0_col3" class="data row0 col3" >1462</td>
#       <td id="T_65069_row0_col4" class="data row0 col4" >43.400000</td>
#       <td id="T_65069_row0_col5" class="data row0 col5" >68</td>
#       <td id="T_65069_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_65069_row0_col7" class="data row0 col7" >No Failure</td>
#     </tr>
#     <tr>
#       <th id="T_65069_level0_row1" class="row_heading level0 row1" >6916</th>
#       <td id="T_65069_row1_col0" class="data row1 col0" >M</td>
#       <td id="T_65069_row1_col1" class="data row1 col1" >300.900000</td>
#       <td id="T_65069_row1_col2" class="data row1 col2" >311.300000</td>
#       <td id="T_65069_row1_col3" class="data row1 col3" >1603</td>
#       <td id="T_65069_row1_col4" class="data row1 col4" >31.800000</td>
#       <td id="T_65069_row1_col5" class="data row1 col5" >190</td>
#       <td id="T_65069_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_65069_row1_col7" class="data row1 col7" >No Failure</td>
#     </tr>
#     <tr>
#       <th id="T_65069_level0_row2" class="row_heading level0 row2" >7899</th>
#       <td id="T_65069_row2_col0" class="data row2 col0" >L</td>
#       <td id="T_65069_row2_col1" class="data row2 col1" >300.900000</td>
#       <td id="T_65069_row2_col2" class="data row2 col2" >312.400000</td>
#       <td id="T_65069_row2_col3" class="data row2 col3" >1364</td>
#       <td id="T_65069_row2_col4" class="data row2 col4" >52.500000</td>
#       <td id="T_65069_row2_col5" class="data row2 col5" >125</td>
#       <td id="T_65069_row2_col6" class="data row2 col6" >0</td>
#       <td id="T_65069_row2_col7" class="data row2 col7" >No Failure</td>
#     </tr>
#     <tr>
#       <th id="T_65069_level0_row3" class="row_heading level0 row3" >5771</th>
#       <td id="T_65069_row3_col0" class="data row3 col0" >L</td>
#       <td id="T_65069_row3_col1" class="data row3 col1" >301.600000</td>
#       <td id="T_65069_row3_col2" class="data row3 col2" >311.200000</td>
#       <td id="T_65069_row3_col3" class="data row3 col3" >1525</td>
#       <td id="T_65069_row3_col4" class="data row3 col4" >43.700000</td>
#       <td id="T_65069_row3_col5" class="data row3 col5" >91</td>
#       <td id="T_65069_row3_col6" class="data row3 col6" >0</td>
#       <td id="T_65069_row3_col7" class="data row3 col7" >No Failure</td>
#     </tr>
#     <tr>
#       <th id="T_65069_level0_row4" class="row_heading level0 row4" >6735</th>
#       <td id="T_65069_row4_col0" class="data row4 col0" >L</td>
#       <td id="T_65069_row4_col1" class="data row4 col1" >301.600000</td>
#       <td id="T_65069_row4_col2" class="data row4 col2" >311.000000</td>
#       <td id="T_65069_row4_col3" class="data row4 col3" >1485</td>
#       <td id="T_65069_row4_col4" class="data row4 col4" >40.100000</td>
#       <td id="T_65069_row4_col5" class="data row4 col5" >142</td>
#       <td id="T_65069_row4_col6" class="data row4 col6" >0</td>
#       <td id="T_65069_row4_col7" class="data row4 col7" >No Failure</td>
#     </tr>
#     <tr>
#       <th id="T_65069_level0_row5" class="row_heading level0 row5" >6141</th>
#       <td id="T_65069_row5_col0" class="data row5 col0" >L</td>
#       <td id="T_65069_row5_col1" class="data row5 col1" >300.800000</td>
#       <td id="T_65069_row5_col2" class="data row5 col2" >310.800000</td>
#       <td id="T_65069_row5_col3" class="data row5 col3" >1486</td>
#       <td id="T_65069_row5_col4" class="data row5 col4" >45.700000</td>
#       <td id="T_65069_row5_col5" class="data row5 col5" >146</td>
#       <td id="T_65069_row5_col6" class="data row5 col6" >0</td>
#       <td id="T_65069_row5_col7" class="data row5 col7" >No Failure</td>
#     </tr>
#     <tr>
#       <th id="T_65069_level0_row6" class="row_heading level0 row6" >6045</th>
#       <td id="T_65069_row6_col0" class="data row6 col0" >L</td>
#       <td id="T_65069_row6_col1" class="data row6 col1" >300.800000</td>
#       <td id="T_65069_row6_col2" class="data row6 col2" >310.900000</td>
#       <td id="T_65069_row6_col3" class="data row6 col3" >1311</td>
#       <td id="T_65069_row6_col4" class="data row6 col4" >55.800000</td>
#       <td id="T_65069_row6_col5" class="data row6 col5" >118</td>
#       <td id="T_65069_row6_col6" class="data row6 col6" >0</td>
#       <td id="T_65069_row6_col7" class="data row6 col7" >No Failure</td>
#     </tr>
#     <tr>
#       <th id="T_65069_level0_row7" class="row_heading level0 row7" >5476</th>
#       <td id="T_65069_row7_col0" class="data row7 col0" >M</td>
#       <td id="T_65069_row7_col1" class="data row7 col1" >302.600000</td>
#       <td id="T_65069_row7_col2" class="data row7 col2" >312.100000</td>
#       <td id="T_65069_row7_col3" class="data row7 col3" >1445</td>
#       <td id="T_65069_row7_col4" class="data row7 col4" >42.000000</td>
#       <td id="T_65069_row7_col5" class="data row7 col5" >181</td>
#       <td id="T_65069_row7_col6" class="data row7 col6" >0</td>
#       <td id="T_65069_row7_col7" class="data row7 col7" >No Failure</td>
#     </tr>
#     <tr>
#       <th id="T_65069_level0_row8" class="row_heading level0 row8" >9651</th>
#       <td id="T_65069_row8_col0" class="data row8 col0" >M</td>
#       <td id="T_65069_row8_col1" class="data row8 col1" >299.100000</td>
#       <td id="T_65069_row8_col2" class="data row8 col2" >310.0000

# %%
## Converting temperature in centigrate from Kelvin [1 K = -272.15 °C  ] 

df["Air temperature [K]"] = df["Air temperature [K]"] - 272.15
df["Process temperature [K]"] = df["Process temperature [K]"] - 272.15

# Renaming temperature in Centigrate(°C) from Kelvin (K)
df.rename(columns={"Air temperature [K]" : "Air temperature [°C]","Process temperature [K]" : "Process temperature [°C]"},inplace=True)

# %%
df["Temperature difference [°C]"] = df["Process temperature [°C]"] - df["Air temperature [°C]"]
df.sample(5)
# Out:
#      Type  Air temperature [°C]  Process temperature [°C]  \
# 5610    L                 30.95                     40.25
# 1222    L                 24.85                     36.15
# 3123    H                 27.85                     37.25
# 4190    H                 30.25                     38.75
# 6723    M                 29.25                     38.45
#
#       Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target  \
# 5610                    1407         41.2              107       0
# 1222                    1399         59.0              135       0
# 3123                    1498         38.5               37       0
# 4190                    1444         40.7              174       0
# 6723                    1565         36.1              110       0
#
#      Failure Type  Temperature difference [°C]
# 5610   No Failure                          9.3
# 1222   No Failure                         11.3
# 3123   No Failure                          9.4
# 4190   No Failure                          8.5
# 6723   No Failure                          9.2

# %%
display(df.shape)
display(df.size)
# Out:
# (10000, 9)
# 90000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Type                         10000 non-null  object
#  1   Air temperature [°C]         10000 non-null  float64
#  2   Process temperature [°C]     10000 non-null  float64
#  3   Rotational speed [rpm]       10000 non-null  int64
#  4   Torque [Nm]                  10000 non-null  float64
#  5   Tool wear [min]              10000 non-null  int64
#  6   Target                       10000 non-null  int64
#  7   Failure Type                 10000 non-null  object
#  8   Temperature difference [°C]  10000 non-null  float64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 703.3+ KB

# %%
df.describe().style.background_gradient(cmap="magma")
# Out:
# <style type="text/css">
# #T_6a8b0_row0_col0, #T_6a8b0_row0_col1, #T_6a8b0_row0_col2, #T_6a8b0_row0_col3, #T_6a8b0_row0_col4, #T_6a8b0_row0_col5, #T_6a8b0_row0_col6 {
#   background-color: #fcfdbf;
#   color: #000000;
# }
# #T_6a8b0_row1_col0, #T_6a8b0_row1_col1, #T_6a8b0_row1_col3, #T_6a8b0_row1_col5, #T_6a8b0_row1_col6, #T_6a8b0_row2_col0, #T_6a8b0_row2_col1, #T_6a8b0_row2_col2, #T_6a8b0_row2_col3, #T_6a8b0_row2_col5, #T_6a8b0_row2_col6, #T_6a8b0_row3_col0, #T_6a8b0_row3_col1, #T_6a8b0_row3_col3, #T_6a8b0_row3_col4, #T_6a8b0_row3_col5, #T_6a8b0_row3_col6, #T_6a8b0_row4_col0, #T_6a8b0_row4_col1, #T_6a8b0_row4_col3, #T_6a8b0_row4_col5, #T_6a8b0_row4_col6, #T_6a8b0_row5_col0, #T_6a8b0_row5_col1, #T_6a8b0_row5_col3, #T_6a8b0_row5_col5, #T_6a8b0_row5_col6, #T_6a8b0_row6_col0, #T_6a8b0_row6_col1, #T_6a8b0_row6_col5, #T_6a8b0_row6_col6, #T_6a8b0_row7_col0, #T_6a8b0_row7_col5, #T_6a8b0_row7_col6 {
#   background-color: #000004;
#   color: #f1f1f1;
# }
# #T_6a8b0_row1_col2 {
#   background-color: #21114e;
#   color: #f1f1f1;
# }
# #T_6a8b0_row1_col4, #T_6a8b0_row5_col4 {
#   background-color: #010106;
#   color: #f1f1f1;
# }
# #T_6a8b0_row2_col4, #T_6a8b0_row4_col4, #T_6a8b0_row6_col3, #T_6a8b0_row7_col1, #T_6a8b0_row7_col3 {
#   background-color: #010005;
#   color: #f1f1f1;
# }
# #T_6a8b0_row3_col2 {
#   background-color: #140e36;
#   color: #f1f1f1;
# }
# #T_6a8b0_row4_col2 {
#   background-color: #1d1147;
#   color: #f1f1f1;
# }
# #T_6a8b0_row5_col2 {
#   background-color: #20114b;
#   color: #f1f1f1;
# }
# #T_6a8b0_row6_col2 {
#   background-color: #241253;
#   color: #f1f1f1;
# }
# #T_6a8b0_row6_col4 {
#   background-color: #020109;
#   color: #f1f1f1;
# }
# #T_6a8b0_row7_col2 {
#   background-color: #5a167e;
#   color: #f1f1f1;
# }
# #T_6a8b0_row7_col4 {
#   background-color: #02020d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6a8b0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6a8b0_level0_col0" class="col_heading level0 col0" >Air temperature [°C]</th>
#       <th id="T_6a8b0_level0_col1" class="col_heading level0 col1" >Process temperature [°C]</th>
#       <th id="T_6a8b0_level0_col2" class="col_heading level0 col2" >Rotational speed [rpm]</th>
#       <th id="T_6a8b0_level0_col3" class="col_heading level0 col3" >Torque [Nm]</th>
#       <th id="T_6a8b0_level0_col4" class="col_heading level0 col4" >Tool wear [min]</th>
#       <th id="T_6a8b0_level0_col5" class="col_heading level0 col5" >Target</th>
#       <th id="T_6a8b0_level0_col6" class="col_heading level0 col6" >Temperature difference [°C]</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6a8b0_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_6a8b0_row0_col0" class="data row0 col0" >10000.000000</td>
#       <td id="T_6a8b0_row0_col1" class="data row0 col1" >10000.000000</td>
#       <td id="T_6a8b0_row0_col2" class="data row0 col2" >10000.000000</td>
#       <td id="T_6a8b0_row0_col3" class="data row0 col3" >10000.000000</td>
#       <td id="T_6a8b0_row0_col4" class="data row0 col4" >10000.000000</td>
#       <td id="T_6a8b0_row0_col5" class="data row0 col5" >10000.000000</td>
#       <td id="T_6a8b0_row0_col6" class="data row0 col6" >10000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6a8b0_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_6a8b0_row1_col0" class="data row1 col0" >27.854930</td>
#       <td id="T_6a8b0_row1_col1" class="data row1 col1" >37.855560</td>
#       <td id="T_6a8b0_row1_col2" class="data row1 col2" >1538.776100</td>
#       <td id="T_6a8b0_row1_col3" class="data row1 col3" >39.986910</td>
#       <td id="T_6a8b0_row1_col4" class="data row1 col4" >107.951000</td>
#       <td id="T_6a8b0_row1_col5" class="data row1 col5" >0.033900</td>
#       <td id="T_6a8b0_row1_col6" class="data row1 col6" >10.000630</td>
#     </tr>
#     <tr>
#       <th id="T_6a8b0_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_6a8b0_row2_col0" class="data row2 col0" >2.000259</td>
#       <td id="T_6a8b0_row2_col1" class="data row2 col1" >1.483734</td>
#       <td id="T_6a8b0_row2_col2" class="data row2 col2" >179.284096</td>
#       <td id="T_6a8b0_row2_col3" class="data row2 col3" >9.968934</td>
#       <td id="T_6a8b0_row2_col4" class="data row2 col4" >63.654147</td>
#       <td id="T_6a8b0_row2_col5" class="data row2 col5" >0.180981</td>
#       <td id="T_6a8b0_row2_col6" class="data row2 col6" >1.001094</td>
#     </tr>
#     <tr>
#       <th id="T_6a8b0_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_6a8b0_row3_col0" class="data row3 col0" >23.150000</td>
#       <td id="T_6a8b0_row3_col1" class="data row3 col1" >33.550000</td>
#       <td id="T_6a8b0_row3_col2" class="data row3 col2" >1168.000000</td>
#       <td id="T_6a8b0_row3_col3" class="data row3 col3" >3.800000</td>
#       <td id="T_6a8b0_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_6a8b0_row3_col5" class="data row3 col5" >0.000000</td>
#       <td id="T_6a8b0_row3_col6" class="data row3 col6" >7.600000</td>
#     </tr>
#     <tr>
#       <th id="T_6a8b0_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_6a8b0_row4_col0" class="data row4 col0" >26.150000</td>
#       <td id="T_6a8b0_row4_col1" class="data row4 col1" >36.650000</td>
#       <td id="T_6a8b0_row4_col2" class="data row4 col2" >1423.000000</td>
#       <td id="T_6a8b0_row4_col3" class="data row4 col3" >33.200000</td>
#       <td id="T_6a8b0_row4_col4" class="data row4 col4" >53.000000</td>
#       <td id="T_6a8b0_row4_col5" class="data row4 col5" >0.000000</td>
#       <td id="T_6a8b0_row4_col6" class="data row4 col6" >9.300000</td>
#     </tr>
#     <tr>
#       <th id="T_6a8b0_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_6a8b0_row5_col0" class="data row5 col0" >27.950000</td>
#       <td id="T_6a8b0_row5_col1" class="data row5 col1" >37.950000</td>
#       <td id="T_6a8b0_row5_col2" class="data row5 col2" >1503.000000</td>
#       <td id="T_6a8b0_row5_col3" class="data row5 col3" >40.100000</td>
#       <td id="T_6a8b0_row5_col4" class="data row5 col4" >108.000000</td>
#       <td id="T_6a8b0_row5_col5" class="data row5 col5" >0.000000</td>
#       <td id="T_6a8b0_row5_col6" class="data row5 col6" >9.800000</td>
#     </tr>
#     <tr>
#       <th id="T_6a8b0_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_6a8b0_row6_col0" class="data row6 col0" >29.350000</td>
#       <td id="T_6a8b0_row6_col1" class="data row6 col1" >38.950000</td>
#       <td id="T_6a8b0_row6_col2" class="data row6 col2" >1612.000000</td>
#       <td id="T_6a8b0_row6_col3" class="data row6 col3" >46.800000</td>
#       <td id="T_6a8b0_row6_col4" class="data row6 col4" >162.000000</td>
#       <td id="T_6a8b0_row6_col5" class="data row6 col5" >0.000000</td>
#       <td id="T_6a8b0_row6_col6" class="data row6 col6" >11.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6a8b0_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_6a8b0_row7_col0" class="data row7 col0" >32.350000</td>
#       <td id="T_6a8b0_row7_col1" class="data row7 col1" >41.650000</td>
#       <td id="T_6a8b0_row7_col2" class="data row7 col2" >2886.000000</td>
#       <td id="T_6a8b0_row7_col3" class="data row7 col3" >76.600000</td>
#       <td id="T_6a8b0_row7_col4" class="data row7 col4" >253.000000</td>
#       <td id="T_6a8b0_row7_col5" class="data row7 col5" >1.000000</td>
#       <td id="T_6a8b0_row7_col6" class="data row7 col6" >12.100000</td>
#     </tr>
#   </tbody>
# </table>

# %%
import missingno as msno
plt.rcParams['font.family'] = 'DejaVu Sans'

msno.matrix(df, figsize=(18,5), fontsize=12, color=(1, 0.38, 0.27));
plt.xticks(rotation=25);

# %%
sns.displot(data=df, x="Air temperature [°C]", kde=True, bins = 100,color = "red", facecolor = "yellow",height = 5, aspect = 3.5);

# %%
sns.displot(data=df, x="Process temperature [°C]", kde=True, bins = 100,color = "red", facecolor = "lime",height = 5, aspect = 3.5);

# %%
sns.displot(data=df, x="Temperature difference [°C]", kde=True, bins = 100,color = "blue", facecolor = "DeepPink",height = 5, aspect = 3.5);

# %%
for col in df[['Type','Target','Failure Type']]:
    print(df[col].value_counts()) 
    print("****"*8)
# Out:
# Type
# L    6000
# M    2997
# H    1003
# Name: count, dtype: int64
# ********************************
# Target
# 0    9661
# 1     339
# Name: count, dtype: int64
# ********************************
# Failure Type
# No Failure                  9652
# Heat Dissipation Failure     112
# Power Failure                 95
# Overstrain Failure            78
# Tool Wear Failure             45
# Random Failures               18
# Name: count, dtype: int64
# ********************************

# %%
ax = plt.figure(figsize=(18,6))
ax = plt.subplot(1,2,1)
ax = sns.countplot(x='Type', data=df)
ax.bar_label(ax.containers[0])
plt.title("Type", fontsize=20,color='Red',font='Times New Roman')
ax =plt.subplot(1,2,2)
ax=df['Type'].value_counts().plot.pie(explode=[0.1, 0.1,0.1],autopct='%1.2f%%',shadow=True);
ax.set_title(label = "Type", fontsize = 20,color='Red',font='Times New Roman');

# %%
ax = plt.figure(figsize=(18,6))
ax = plt.subplot(1,2,1)
ax = sns.countplot(x='Target', data=df)
ax.bar_label(ax.containers[0])
plt.title("Target", fontsize=20,color='Red',font='Times New Roman')
ax =plt.subplot(1,2,2)
ax=df['Target'].value_counts().plot.pie(explode=[0.1, 0.1],autopct='%1.2f%%',shadow=True);
ax.set_title(label = "Target", fontsize = 20,color='Red',font='Times New Roman');

# %%
df.head(2)
# Out:
#   Type  Air temperature [°C]  Process temperature [°C]  \
# 0    M                 25.95                     36.45
# 1    L                 26.05                     36.55
#
#    Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target Failure Type  \
# 0                    1551         42.8                0       0   No Failure
# 1                    1408         46.3                3       0   No Failure
#
#    Temperature difference [°C]
# 0                         10.5
# 1                         10.5

# %%
plt.figure(figsize=(18,7))
sns.scatterplot(data=df, x="Torque [Nm]", y="Rotational speed [rpm]", hue="Failure Type",palette="tab10");

# %%
plt.figure(figsize=(18,7))
sns.scatterplot(data=df, x="Torque [Nm]", y="Rotational speed [rpm]", hue="Target",palette="tab10");

# %%
plt.figure(figsize=(18,7))
sns.scatterplot(data=df, x="Torque [Nm]", y="Rotational speed [rpm]", hue="Type",palette="tab10");

# %%
df.head(2)
# Out:
#   Type  Air temperature [°C]  Process temperature [°C]  \
# 0    M                 25.95                     36.45
# 1    L                 26.05                     36.55
#
#    Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target Failure Type  \
# 0                    1551         42.8                0       0   No Failure
# 1                    1408         46.3                3       0   No Failure
#
#    Temperature difference [°C]
# 0                         10.5
# 1                         10.5

# %%
import statistics

def plot_hist(feature):
    fig, ax = plt.subplots(2, 1, figsize=(18, 8))
    
    sns.histplot(data = df[feature], kde = True, ax = ax[0],color='pink')

    ax[0].axvline(x = df[feature].mean(), color = 'Magenta', linestyle = '--', linewidth = 2, label = 'Mean: {}'.format(round(df[feature].mean(), 3)))
    ax[0].axvline(x = df[feature].median(), color = 'lime', linewidth = 2, label = 'Median: {}'.format(round(df[feature].median(), 3)))
    ax[0].axvline(x = statistics.mode(df[feature]), color = 'brown', linewidth = 2, label = 'Mode: {}'.format(statistics.mode(df[feature])))
    ax[0].legend()
    
    sns.boxplot(x = df[feature], ax = ax[1],color='pink')
    
    plt.show()

plot_hist('Torque [Nm]')

# %%
def plot_hist(feature):
    fig, ax = plt.subplots(2, 1, figsize=(18, 8))
    
    sns.histplot(data = df[feature], kde = True, ax = ax[0],color='green')

    ax[0].axvline(x = df[feature].mean(), color = 'red', linestyle = '--', linewidth = 2, label = 'Mean: {}'.format(round(df[feature].mean(), 3)))
    ax[0].axvline(x = df[feature].median(), color = 'orange', linewidth = 2, label = 'Median: {}'.format(round(df[feature].median(), 3)))
    ax[0].axvline(x = statistics.mode(df[feature]), color = 'brown', linewidth = 2, label = 'Mode: {}'.format(statistics.mode(df[feature])))
    ax[0].legend()
    
    sns.boxplot(x = df[feature], ax = ax[1],color='green')
    
    plt.show()

plot_hist('Rotational speed [rpm]')

# %%
sns.displot(data=df, x="Torque [Nm]", col="Type", kind="kde");

# %%
sns.displot(data=df, x="Rotational speed [rpm]", col="Type", kind="kde");

# %%
sns.relplot(data=df, x="Torque [Nm]", y="Rotational speed [rpm]", hue="Failure Type",col="Type",palette='tab10');

# %%
## Feature Selection

# %%
import category_encoders as ce
encoder = ce.OrdinalEncoder(cols=['Type','Failure Type'])
df = encoder.fit_transform(df)
df.head(2)
# Out:
#    Type  Air temperature [°C]  Process temperature [°C]  \
# 0     1                 25.95                     36.45
# 1     2                 26.05                     36.55
#
#    Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target  Failure Type  \
# 0                    1551         42.8                0       0             1
# 1                    1408         46.3                3       0             1
#
#    Temperature difference [°C]
# 0                         10.5
# 1                         10.5

# %%
from sklearn.preprocessing import LabelEncoder
scaler = LabelEncoder()
df['Failure Type'] = scaler.fit_transform(df['Failure Type'])

# %%
X = df.drop(columns="Failure Type" , axis=1)
y = df["Failure Type"]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=21)

# %%
plt.figure(figsize=(18,5))
ax = sns.countplot(x = y_train, palette = 'tab10')
t= len(y_train)
for p in ax.patches:
    percentage = f'{100 * p.get_height() / t:.1f}%\n'
    x = p.get_x() + p.get_width() / 2
    y = p.get_height()
    ax.annotate(percentage, (x, y), ha='center', va='center')
plt.show()

# %%
plt.figure(figsize=(18,5))
ax = sns.countplot(x = y_test, palette = 'tab10')
t= len(y_test)
for p in ax.patches:
    percentage = f'{100 * p.get_height() / t:.1f}%\n'
    x = p.get_x() + p.get_width() / 2
    y = p.get_height()
    ax.annotate(percentage, (x, y), ha='center', va='center')
plt.show()

# %%
## Logistic Regression

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression

# Logistic Regression
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
y_pred_lr = logreg.predict(X_test)

log_train = round(logreg.score(X_train, y_train) * 100, 2)
log_accuracy = round(accuracy_score(y_pred_lr, y_test) * 100, 2)

print("Training Accuracy    :", log_train, "%")
print("Model Accuracy Score :", log_accuracy, "%")
print("\033[1m--------------------------------------------------------\033[0m")
print("Classification_Report: \n", classification_report(y_test, y_pred_lr))
print("\033[1m--------------------------------------------------------\033[0m")

# Updated Confusion Matrix Visualization
cm = confusion_matrix(y_test, y_pred_lr)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=logreg.classes_)
disp.plot(cmap='Blues')  # You can customize the color map
plt.title('Confusion Matrix')
plt.show()
# Out:
# Training Accuracy    : 96.74 %
# Model Accuracy Score : 96.25 %
# --------------------------------------------------------
# Classification_Report:
#                precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      1921
#            1       0.00      0.00      0.00        19
#            2       0.00      0.00      0.00         9
#            3       0.71      0.31      0.43        16
#            4       0.00      0.00      0.00         3
#            5       0.00      0.00      0.00        32
#
#     accuracy                           0.96      2000
#    macro avg       0.28      0.22      0.24      2000
# weighted avg       0.93      0.96      0.95      2000
#
# --------------------------------------------------------

# %%
## Decision Tree

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier

# Decision Tree Classifier
decision = DecisionTreeClassifier()
decision.fit(X_train, y_train)
y_pred_dec = decision.predict(X_test)

decision_train = round(decision.score(X_train, y_train) * 100, 2)
decision_accuracy = round(accuracy_score(y_pred_dec, y_test) * 100, 2)

print("Training Accuracy    :", decision_train, "%")
print("Model Accuracy Score :", decision_accuracy, "%")
print("\033[1m--------------------------------------------------------\033[0m")
print("Classification_Report: \n", classification_report(y_test, y_pred_dec))
print("\033[1m--------------------------------------------------------\033[0m")

# Updated Confusion Matrix Visualization
cm = confusion_matrix(y_test, y_pred_dec)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=decision.classes_)
disp.plot(cmap='Blues')  # Customize colormap
plt.title('Confusion Matrix')
plt.show()
# Out:
# Training Accuracy    : 100.0 %
# Model Accuracy Score : 99.35 %
# --------------------------------------------------------
# Classification_Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1921
#            1       0.85      0.89      0.87        19
#            2       0.82      1.00      0.90         9
#            3       0.92      0.75      0.83        16
#            4       0.00      0.00      0.00         3
#            5       0.97      0.97      0.97        32
#
#     accuracy                           0.99      2000
#    macro avg       0.76      0.77      0.76      2000
# weighted avg       0.99      0.99      0.99      2000
#
# --------------------------------------------------------

# %%
## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Random Forest Classifier
random_forest = RandomForestClassifier(n_estimators=100)
random_forest.fit(X_train, y_train)
y_pred_rf = random_forest.predict(X_test)

random_forest_train = round(random_forest.score(X_train, y_train) * 100, 2)
random_forest_accuracy = round(accuracy_score(y_pred_rf, y_test) * 100, 2)

print("Training Accuracy    :", random_forest_train, "%")
print("Model Accuracy Score :", random_forest_accuracy, "%")
print("\033[1m--------------------------------------------------------\033[0m")
print("Classification_Report: \n", classification_report(y_test, y_pred_rf))
print("\033[1m--------------------------------------------------------\033[0m")

# Updated Confusion Matrix Visualization
cm = confusion_matrix(y_test, y_pred_rf)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=random_forest.classes_)
disp.plot(cmap='Blues')  # Customize colormap
plt.title('Confusion Matrix')
plt.show()
# Out:
# Training Accuracy    : 100.0 %
# Model Accuracy Score : 99.55 %
# --------------------------------------------------------
# Classification_Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1921
#            1       0.86      0.95      0.90        19
#            2       1.00      0.78      0.88         9
#            3       0.88      0.94      0.91        16
#            4       0.00      0.00      0.00         3
#            5       0.97      0.97      0.97        32
#
#     accuracy                           1.00      2000
#    macro avg       0.78      0.77      0.78      2000
# weighted avg       0.99      1.00      0.99      2000
#
# --------------------------------------------------------

# %%
##SVM

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Support Vector Machines
svc = SVC()
svc.fit(X_train, y_train)
y_pred_svc = svc.predict(X_test)

svc_train = round(svc.score(X_train, y_train) * 100, 2)
svc_accuracy = round(accuracy_score(y_pred_svc, y_test) * 100, 2)

print("Training Accuracy    :", svc_train, "%")
print("Model Accuracy Score :", svc_accuracy, "%")
print("\033[1m--------------------------------------------------------\033[0m")
print("Classification_Report: \n", classification_report(y_test, y_pred_svc))
print("\033[1m--------------------------------------------------------\033[0m")

# Updated Confusion Matrix Visualization
cm = confusion_matrix(y_test, y_pred_svc)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=svc.classes_)
disp.plot(cmap='Blues')  # Customize colormap
plt.title('Confusion Matrix')
plt.show()
# Out:
# Training Accuracy    : 96.64 %
# Model Accuracy Score : 96.05 %
# --------------------------------------------------------
# Classification_Report:
#                precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      1921
#            1       0.00      0.00      0.00        19
#            2       0.00      0.00      0.00         9
#            3       0.00      0.00      0.00        16
#            4       0.00      0.00      0.00         3
#            5       0.00      0.00      0.00        32
#
#     accuracy                           0.96      2000
#    macro avg       0.16      0.17      0.16      2000
# weighted avg       0.92      0.96      0.94      2000
#
# --------------------------------------------------------

# %%
## Building the Model

# %%
models = pd.DataFrame({
    'Model': [
        'Support Vector Machines', 'Logistic Regression', 'Random Forest',
        'Decision Tree'
    ],
    
    'Training Accuracy':
    [log_train, svc_train, decision_train, random_forest_train],
    
    'Model Accuracy Score': [
        log_accuracy, svc_accuracy, decision_accuracy, random_forest_accuracy
    ]
})

# %%
pd.options.display.float_format = "{:.2f}".format

# Sort and style the DataFrame
styled_df = models.sort_values(by='Model Accuracy Score', ascending=False).style\
    .background_gradient(cmap='coolwarm')\
    .set_properties(**{
        'font-family': 'Arial',  # Replacing 'Lucida Calligraphy' with a universal font
        'color': 'LightGreen',   # Fixed typo
        'font-size': '15px'
    })

styled_df
# Out:
# <style type="text/css">
# #T_45664_row0_col0, #T_45664_row1_col0, #T_45664_row2_col0, #T_45664_row3_col0 {
#   font-family: Arial;
#   color: LightGreen;
#   font-size: 15px;
# }
# #T_45664_row0_col1, #T_45664_row0_col2, #T_45664_row1_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
#   font-family: Arial;
#   color: LightGreen;
#   font-size: 15px;
# }
# #T_45664_row1_col2 {
#   background-color: #c83836;
#   color: #f1f1f1;
#   font-family: Arial;
#   color: LightGreen;
#   font-size: 15px;
# }
# #T_45664_row2_col1 {
#   background-color: #4358cb;
#   color: #f1f1f1;
#   font-family: Arial;
#   color: LightGreen;
#   font-size: 15px;
# }
# #T_45664_row2_col2 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
#   font-family: Arial;
#   color: LightGreen;
#   font-size: 15px;
# }
# #T_45664_row3_col1, #T_45664_row3_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
#   font-family: Arial;
#   color: LightGreen;
#   font-size: 15px;
# }
# </style>
# <table id="T_45664">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_45664_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_45664_level0_col1" class="col_heading level0 col1" >Training Accuracy</th>
#       <th id="T_45664_level0_col2" class="col_heading level0 col2" >Model Accuracy Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_45664_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_45664_row0_col0" class="data row0 col0" >Decision Tree</td>
#       <td id="T_45664_row0_col1" class="data row0 col1" >100.000000</td>
#       <td id="T_45664_row0_col2" class="data row0 col2" >99.550000</td>
#     </tr>
#     <tr>
#       <th id="T_45664_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_45664_row1_col0" class="data row1 col0" >Random Forest</td>
#       <td id="T_45664_row1_col1" class="data row1 col1" >100.000000</td>
#       <td id="T_45664_row1_col2" class="data row1 col2" >99.350000</td>
#     </tr>
#     <tr>
#       <th id="T_45664_level0_row2" class="row_heading level0 row2" >0</th>
#       <td id="T_45664_row2_col0" class="data row2 col0" >Support Vector Machines</td>
#       <td id="T_45664_row2_col1" class="data row2 col1" >96.740000</td>
#       <td id="T_45664_row2_col2" class="data row2 col2" >96.250000</td>
#     </tr>
#     <tr>
#       <th id="T_45664_level0_row3" class="row_heading level0 row3" >1</th>
#       <td id="T_45664_row3_col0" class="data row3 col0" >Logistic Regression</td>
#       <td id="T_45664_row3_col1" class="data row3 col1" >96.640000</td>
#       <td id="T_45664_row3_col2" class="data row3 col2" >96.050000</td>
#     </tr>
#   </tbody>
# </table>

# %%
prediction1 = random_forest.predict(X_test)
print(prediction1)
# Out:
# [0 0 0 ... 0 0 0]

# %%
cross_checking = pd.DataFrame({'Actual' : y_test , 'Predicted' : prediction1})
cross_checking.sample(5).style.background_gradient(
        cmap='coolwarm').set_properties(**{
            'font-family': 'Lucida Calligraphy',
            'color': 'LigntGreen',
            'font-size': '15px'
        })
# Out:
# <style type="text/css">
# #T_ecccf_row0_col0, #T_ecccf_row0_col1, #T_ecccf_row1_col0, #T_ecccf_row1_col1, #T_ecccf_row2_col0, #T_ecccf_row2_col1, #T_ecccf_row3_col0, #T_ecccf_row3_col1, #T_ecccf_row4_col0, #T_ecccf_row4_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# </style>
# <table id="T_ecccf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ecccf_level0_col0" class="col_heading level0 col0" >Actual</th>
#       <th id="T_ecccf_level0_col1" class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ecccf_level0_row0" class="row_heading level0 row0" >4458</th>
#       <td id="T_ecccf_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_ecccf_row0_col1" class="data row0 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_ecccf_level0_row1" class="row_heading level0 row1" >5468</th>
#       <td id="T_ecccf_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_ecccf_row1_col1" class="data row1 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_ecccf_level0_row2" class="row_heading level0 row2" >5746</th>
#       <td id="T_ecccf_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_ecccf_row2_col1" class="data row2 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_ecccf_level0_row3" class="row_heading level0 row3" >318</th>
#       <td id="T_ecccf_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_ecccf_row3_col1" class="data row3 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_ecccf_level0_row4" class="row_heading level0 row4" >4396</th>
#       <td id="T_ecccf_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_ecccf_row4_col1" class="data row4 col1" >0</td>
#     </tr>
#   </tbody>
# </table>
